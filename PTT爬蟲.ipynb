# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Baseball/index9995.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")

#抓看板文章標題和作者
for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-metaline').text)
    except:
        continue
# Out:
# [閒聊] 為什麼遲遲不換下霸能？
# 作者: 作者gentleman888 ()
# [問題] 二世怎麼了？
# 作者: 作者Qpera (烏拉博士)
# [討論] 不怕左打的林羿豪
# 作者: 作者Duke200 (Duke)
# [閒聊] 雙林放到現在還能主宰聯盟嗎？
# 作者: 作者DoBahaha (Dobahaha)
# [炸裂] 唐肇廷
# 作者: 作者trokymmr (數綿羊)
# Re: [問題] 二世怎麼了？
# 作者: 作者Owada (大和田)
# [閒聊] 鄉長劇場
# 作者: 作者judelawww (  )
# Re: [閒聊] 洪中沒了lamigo球團
# 作者: 作者dahanjian (強煎飯)
# [問題]陳鴻文怎麼了
# 作者: 作者yun0615ch (阿毛毛)
# [討論] 佛刀 是不是變更強？
# 作者: 作者coffee77 (睡覺可以忘記很多事)
# [閒聊] 統一獅 再見安打 樂天桃猿本季首敗
# 作者: 作者aaronshell (那就是排骨酥湯啊)
# [分享] CPBL戰績
# 作者: 作者SuperBMW (Pulizu普麗珠)
# [分享] 今日 羅傑斯 索沙
# 作者: 作者shishe (Lemoney Snicket)
# [分享] 今日陳禹勳
# 作者: 作者Paul1021 (胡迪)
# [分享] 今日唐肇廷
# 作者: 作者innocent8675 (坤溪戴維斯)
# [閒聊] 林安可的再見安打球 林益全守得下來嗎？
# 作者: 作者gentleman888 ()
# [閒聊] 九下林英傑站在牛棚投手板想什麼？
# 作者: 作者BlakeSnell (2.1局賽揚)
# [閒聊] 龍貓是不是還不太行
# 作者: 作者QchchQ (情比金堅)
# [新聞] 稱紅襪遭懲處不公平　Ortiz：所有人都這樣做
# 作者: 作者saiulbb (#KEEP MLB GREAT!)
# [新聞] MLB／偷暗號出來背鍋？紅襪重播員否認作弊
# 作者: 作者saiulbb (#KEEP MLB GREAT!)

# %%
# 抓看板文章標題和連結
import requests
from bs4 import BeautifulSoup
url="https://www.ptt.cc/bbs/Food/index.html"

def get_all_href(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    results = soup.select("div.title")
    for item in results:
        a_item = item.select_one("a")
        title = item.text
        if a_item:
            print(title, 'https://www.ptt.cc'+ a_item.get('href'))
        
for page in range(3,6):
    r = requests.get(url)
    soup = BeautifulSoup(r.text,"html.parser")
    btn = soup.select('div.btn-group > a')
    up_page_href = btn[3]['href']
    next_page_url = 'https://www.ptt.cc' + up_page_href
    url = next_page_url
    get_all_href(url = url)
# Out:
# [廣宣] 台中北區 早安公雞農場晨食
#  https://www.ptt.cc/bbs/Food/M.1588128604.A.DE0.html
#
# Re: [食記] 台中牛排 服務態度不推薦 赤鬼炙燒牛排
#  https://www.ptt.cc/bbs/Food/M.1588130233.A.6EA.html
#
# [食記] 花蓮韋記 重慶小麵 川味熱炒太道地
#  https://www.ptt.cc/bbs/Food/M.1588135242.A.51B.html
#
# [食記] 嘉義 永大義式冰店 YongDa Gelato
#  https://www.ptt.cc/bbs/Food/M.1588137519.A.F6C.html
#
# [食記] 台北 秦老師豆漿店-推獅子頭蛋餅、韭菜盒
#  https://www.ptt.cc/bbs/Food/M.1588142671.A.99C.html
#
# [食記] 台中 火鍋280元起自助吧吃到飽壽星送肉盤
#  https://www.ptt.cc/bbs/Food/M.1588151308.A.CEE.html
#
# [食記] 首爾弘大 可以做足浴Spa的藥茶房咖啡廳
#  https://www.ptt.cc/bbs/Food/M.1588152168.A.705.html
#
# [食記] 台北五分埔 網美魯肉飯－夯・魯肉飯
#  https://www.ptt.cc/bbs/Food/M.1588153114.A.CD3.html
#
# [食記] 台北大安 TK SEAFOOD & STEAK 沒失誤過的牛排店
#  https://www.ptt.cc/bbs/Food/M.1588154699.A.036.html
#
# [食記] 台北慕舍酒店 Molino de Urdaniz
#  https://www.ptt.cc/bbs/Food/M.1588155473.A.A54.html
#
# Fw: [食記] [新竹] 翻白眼鬆餅站 ～多魚選、昏倒雞?!
#  https://www.ptt.cc/bbs/Food/M.1588157074.A.3BE.html
#
# [食記] 台南北區，黃氏波霸奶茶專賣店
# ...

# %%
r = requests.get( 'https://www.ptt.cc/bbs/Food/M.1588135242.A.51B.html')
soup = BeautifulSoup(r.text, "lxml")
results = soup.find('div', {'id':'main-content'}).text
print(results)

target_content = u'※ 發信站: 批踢踢實業坊(ptt.cc),'

#去除掉 target_content
content = results.split(target_content)
content
# Out:
# 作者ting121067 (阿白)看板Food標題[食記] 花蓮韋記 重慶小麵 熱炒川菜  太道地拉時間Wed Apr 29 12:40:37 2020
#    餐廳名稱：花蓮韋記重慶小麵 川味熱炒
#    消費時間：2020年/4月
#    地址： 973花蓮縣吉安鄉海岸路184號
#    電話：03 8538198
#    營業時間：一公休 早九晚九
#
# 圖文並茂網誌版http://ting1688.me/?p=401
#
#
# 出差，總是發現在地美食的好時機。
#
# 這次來花蓮吉安，想說平日來，開的店也不多。應該不會有什麼特別的店。
#
# 誰知道一進門就覺得這家店一定好吃，畢竟在偏遠的地方要聚集些人潮，一定是有它厲害
# 的地方啊！
#
#
#
#
# 韋記重慶小麵 川味熱炒
# 這家在花蓮縣吉安鄉海岸路旁的重慶道地美食，招牌算顯眼好找，路邊也好停車。來花蓮
# 玩順路繞過來也很合情合理。
#
#
#
# 進門後，處處可見老闆娘手寫的告示牌及菜色簡介。沒有多餘的裝潢擺設，沒有過多的客
# 套服務。只有老闆及老闆娘，想把重慶道地美食，分享給大家的心。
#
# 菜單先上。
#
# 說實在的，如果多人來，會比較好點菜。這次我們兩個，點了乾扁四季豆、滷味三拼、酸
# 辣粉、招牌麵。
#
#
# 韋記重慶小麵 川味熱炒 菜單
# 簡單的花生、蔥蒜、麵條及一些辛香料，吃起來確一點都不簡單。也不用擔心太辣會不敢
# 吃，入口後，麻的口感，帶給你的感受會更真實一點。
#
#
# 韋記重慶小麵 川味熱炒 招牌麵
# 比起招牌麵，酸辣粉更多了些酸的感覺，均勻攪拌後，讓粉條充分沾滿酸辣醬汁，一口吸
# 允入喉。味道的層次是很豐富多變的。具體來說有加了什麼其實我也不知道，但我想這麼
# 道地的口味，所有的調味跟配料是缺一不可的。真心覺得酸辣粉必須點
#
#
# 韋記重慶小麵 川味熱炒 酸辣粉
# 滷味三拼，豆干、海帶拚豬皮，滷味比較沒有特別的地方。可點可不點。
#
#
# 比起乾扁四季豆，其實我更想點水煮魚、口水雞，還有每個隔壁桌都點的水煮牛肉，無奈
# 只有兩個人。但不用擔心，這一定是下次會再來的店。中規中矩的乾扁四季豆，還算好吃
# 。
#
#
# 乾扁四季豆
# 其實對料理我真的不熟，我沒辦法吃一口，就知道這道料理用了什麼食物及配料，我也不
# ...

# %%
content[0]
# Out:
# '作者ting121067 (阿白)看板Food標題[食記] 花蓮韋記 重慶小麵 熱炒川菜  太道地拉時間Wed Apr 29 12:40:37 2020\n   餐廳名稱：花蓮韋記重慶小麵 川味熱炒\n   消費時間：2020年/4月\n   地址： 973花蓮縣吉安鄉海岸路184號\n   電話：03 8538198\n   營業時間：一公休 早九晚九\n\n圖文並茂網誌版http://ting1688.me/?p=401\n\n\n出差，總是發現在地美食的好時機。\n\n這次來花蓮吉安，想說平日來，開的店也不多。應該不會有什麼特別的店。\n\n誰知道一進門就覺得這家店一定好吃，畢竟在偏遠的地方要聚集些人潮，一定是有它厲害\n的地方啊！\n\n\n\n\n韋記重慶小麵 川味熱炒\n這家在花蓮縣吉安鄉海岸路旁的重慶道地美食，招牌算顯眼好找，路邊也好停車。來花蓮\n玩順路繞過來也很合情合理。\n\n\n\n進門後，處處可見老闆娘手寫的告示牌及菜色簡介。沒有多餘的裝潢擺設，沒有過多的客\n套服務。只有老闆及老闆娘，想把重慶道地美食，分享給大家的心。\n\n菜單先上。\n\n說實在的，如果多人來，會比較好點菜。這次我們兩個，點了乾扁四季豆、滷味三拼、酸\n辣粉、招牌麵。\n\n\n韋記重慶小麵 川味熱炒 菜單\n簡單的花生、蔥蒜、麵條及一些辛香料，吃起來確一點都不簡單。也不用擔心太辣會不敢\n吃，入口後，麻的口感，帶給你的感受會更真實一點。\n\n\n韋記重慶小麵 川味熱炒 招牌麵\n比起招牌麵，酸辣粉更多了些酸的感覺，均勻攪拌後，讓粉條充分沾滿酸辣醬汁，一口吸\n允入喉。味道的層次是很豐富多變的。具體來說有加了什麼其實我也不知道，但我想這麼\n道地的口味，所有的調味跟配料是缺一不可的。真心覺得酸辣粉必須點\n\n\n韋記重慶小麵 川味熱炒 酸辣粉\n滷味三拼，豆干、海帶拚豬皮，滷味比較沒有特別的地方。可點可不點。\n\n\n比起乾扁四季豆，其實我更想點水煮魚、口水雞，還有每個隔壁桌都點的水煮牛肉，無奈\n只有兩個人。但不用擔心，這一定是下次會再來的店。中規中矩的乾扁四季豆，還算好吃\n。\n\n\n乾扁四季豆\n其實對料理我真的不熟，我沒辦法吃一口，就知道這道料理用了什麼食物及配料，我也不\n是厲害的美食家或部落客，能夠厲害的接了很多的合作或業配，我只是一個想用最
# ...

# %%
date = soup.find('span', {'class':'article-meta-value'}).text
# content = content.split(date)

#print(content)

#去除掉文末 --

main_content = content[0].replace(date, '')
main_content
# Out:
# '作者看板Food標題[食記] 花蓮韋記 重慶小麵 熱炒川菜  太道地拉時間Wed Apr 29 12:40:37 2020\n   餐廳名稱：花蓮韋記重慶小麵 川味熱炒\n   消費時間：2020年/4月\n   地址： 973花蓮縣吉安鄉海岸路184號\n   電話：03 8538198\n   營業時間：一公休 早九晚九\n\n圖文並茂網誌版http://ting1688.me/?p=401\n\n\n出差，總是發現在地美食的好時機。\n\n這次來花蓮吉安，想說平日來，開的店也不多。應該不會有什麼特別的店。\n\n誰知道一進門就覺得這家店一定好吃，畢竟在偏遠的地方要聚集些人潮，一定是有它厲害\n的地方啊！\n\n\n\n\n韋記重慶小麵 川味熱炒\n這家在花蓮縣吉安鄉海岸路旁的重慶道地美食，招牌算顯眼好找，路邊也好停車。來花蓮\n玩順路繞過來也很合情合理。\n\n\n\n進門後，處處可見老闆娘手寫的告示牌及菜色簡介。沒有多餘的裝潢擺設，沒有過多的客\n套服務。只有老闆及老闆娘，想把重慶道地美食，分享給大家的心。\n\n菜單先上。\n\n說實在的，如果多人來，會比較好點菜。這次我們兩個，點了乾扁四季豆、滷味三拼、酸\n辣粉、招牌麵。\n\n\n韋記重慶小麵 川味熱炒 菜單\n簡單的花生、蔥蒜、麵條及一些辛香料，吃起來確一點都不簡單。也不用擔心太辣會不敢\n吃，入口後，麻的口感，帶給你的感受會更真實一點。\n\n\n韋記重慶小麵 川味熱炒 招牌麵\n比起招牌麵，酸辣粉更多了些酸的感覺，均勻攪拌後，讓粉條充分沾滿酸辣醬汁，一口吸\n允入喉。味道的層次是很豐富多變的。具體來說有加了什麼其實我也不知道，但我想這麼\n道地的口味，所有的調味跟配料是缺一不可的。真心覺得酸辣粉必須點\n\n\n韋記重慶小麵 川味熱炒 酸辣粉\n滷味三拼，豆干、海帶拚豬皮，滷味比較沒有特別的地方。可點可不點。\n\n\n比起乾扁四季豆，其實我更想點水煮魚、口水雞，還有每個隔壁桌都點的水煮牛肉，無奈\n只有兩個人。但不用擔心，這一定是下次會再來的店。中規中矩的乾扁四季豆，還算好吃\n。\n\n\n乾扁四季豆\n其實對料理我真的不熟，我沒辦法吃一口，就知道這道料理用了什麼食物及配料，我也不\n是厲害的美食家或部落客，能夠厲害的接了很多的合作或業配，我只是一個想用最簡單的\n文字跟大家分享我生活
# ...

# %%
date
# Out:
# 'ting121067 (阿白)'

# %% [markdown]
# ### 抓看版文章標題及文章內之作者，看板，標題，時間

# %%
def get_article_content(article_url):
    r = requests.get(article_url)
    soup = BeautifulSoup(r.text, "lxml")
    results = soup.select('span.article-meta-value')
    if results:
        print('作者:', results[0].text)
        print('看板:', results[1].text)
        print('標題:', results[2].text)
        print('時間:', results[3].text)

# %%
import requests
from bs4 import BeautifulSoup
url="https://www.ptt.cc/bbs/Food/index.html"
    
def get_all_href(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    results = soup.select("div.title")
    for item in results:
        a_item = item.select_one("a")
        if a_item:
            get_article_content(article_url='https://www.ptt.cc'+a_item.get('href'))
    print('------------------ next page ------------------')
    
for page in range(3,6):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    btn = soup.select('div.btn-group > a')
    if btn:
        next_page_url = 'https://www.ptt.cc' + btn[3]['href']
        url = next_page_url
        print('page:', url)
        get_all_href(url = url)
# Out:
# page: https://www.ptt.cc/bbs/Food/index7005.html
# 作者: rikabear (大隻熊)
# 看板: Food
# 標題: [廣宣] 台中北區 早安公雞農場晨食
# 時間: Wed Apr 29 10:50:01 2020
# 作者: godgod777 (Tim)
# 看板: Food
# 標題: Re: [食記] 台中牛排 服務態度不推薦 赤鬼炙燒牛排
# 時間: Wed Apr 29 11:17:11 2020
# 作者: ting121067 (阿白)
# 看板: Food
# 標題: [食記] 花蓮韋記 重慶小麵 熱炒川菜  太道地拉
# 時間: Wed Apr 29 12:40:37 2020
# 作者: hibabino (黛西)
# 看板: Food
# 標題: [食記] 嘉義 永大義式冰店 YongDa Gelato
# 時間: Wed Apr 29 13:18:33 2020
# 作者: tiantian27 (teresa)
# 看板: Food
# 標題: [食記] 台北 秦老師豆漿店-推獅子頭蛋餅、韭菜盒
# 時間: Wed Apr 29 14:44:29 2020
# 作者: icyqq (黛咪食旅)
# 看板: Food
# 標題: [食記] 台中 火鍋280元起自助吧吃到飽壽星送肉盤
# 時間: Wed Apr 29 17:08:23 2020
# 作者: vivianlou (RealViKey)
# 看板: Food
# 標題: [食記] 首爾弘大 可以做足浴Spa的藥茶房咖啡廳
# 時間: Wed Apr 29 17:22:46 2020
# 作者: kelly723 (FattyCat)
# 看板: Food
# 標題: [食記]台北五分埔網美魯肉飯－夯・魯肉飯
# 時間: Wed Apr 29 17:38:32 2020
# 作者: AlphaD (DD)
# 看板: Food
# 標題: [食記] 台北大安 TK SEAFOOD & STEAK 沒失誤過的牛排店
# 時間: Wed Apr 29 18:04:53 2020
# 作者: yuan2734 (yuan)
# 看板: Food
# 標題: [食記] 台北慕舍酒店 Molino de Urdaniz
# ...

# %%
import requests

from bs4 import BeautifulSoup



def checkformat(soup, class_tag, data, index, url):

    try:

        content = soup.select(class_tag)[index].text

    except:

        content='null'

    return content

# %%
for page in range(1,3):

    article_href = []

    url = 'https://www.ptt.cc/bbs/Gossiping/index'+str(page)+'.html'

    payload = {'form':'/bbs/stock/index.html',

               'yes':'yes'

              }

    rs=requests.session()

    res=rs.post('https://www.ptt.cc/ask/over18',verify=False,data=payload)

    res=rs.get(url,verify=False)

  

    soup = BeautifulSoup(res.text,"html.parser")

    results = soup.select("div.title")

  



    for item in results:

        try:

            item_href = item.select_one("a").get("href")

            article_href.append(item_href)

        except:

            continue;

  

    for pcontent in range(len(article_href)):           

        payload = {'form':article_href[pcontent],

                   'yes':'yes'

                  }

        rs=requests.session()

        res=rs.post('https://www.ptt.cc/ask/over18',verify=False,data=payload)

        res = rs.get('https://www.ptt.cc'+article_href[pcontent],verify=False,data=payload)

        soup = BeautifulSoup(res.text, "lxml")

        results = soup.select('span.article-meta-value')

        if len(results)>3:

            #作者 看板 標題 時間

            print(results[0].text)

            print(results[1].text)

            print(results[2].text)

            print(results[3].text)

        else:



            continue;

        #content 文章內文

        date = checkformat(soup, '.article-meta-value', 'date', 3, url)

        if date=='null':

            continue;

        #content 文章內文

        content = soup.find(id="main-content").text

        target_content = u'※ 發信站: 批踢踢實業坊(ptt.cc),'

        #去除掉 target_content

        content = content.split(target_content)

        #print(content)

        content = content[0].split(date)

        #print(content)

        #去除掉文末 --

        main_content = content[1].replace('--', '')

        #印出內文

        print(main_content)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\user\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\user\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...
