# %%
import pandas as pd
import re, time, requests
from selenium import webdriver
from bs4 import BeautifulSoup
# from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By

# %%
## 搜尋貼文連結

def FindLinks(url, n):
    Links = []
    driver.get(url)
    for i in range(n):
        time.sleep(2)
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    # 這裡會跳出要我們登入的大畫面，找到「稍後再說」的按鈕並點擊
    #driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
    soup = BeautifulSoup(driver.page_source)
    posts = soup.findAll('div', {'class':'clearfix y_c3pyo2ta3'})
    for i in posts:
        Links.append('https://www.facebook.com' + i.find('a',{'class':'_5pcq'}).attrs['href'].split('?',2)[0])
    return Links

# %%
## 展開所有留言

def expand(url):
    driver.get(url)
    try:
        driver.find_element_by_xpath('//a[@lang="en_US"]').click()
    except:
        print("Now is in EN_US")
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    # 點擊「comments」，藉以展開留言
    try:
        driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
        time.sleep(1)
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(1)
        driver.find_element_by_id('expanding_cta_close_button').click() 
    except:
        print('There is no comment!')
    k = 1
    while k != 0:
        k = 0
        for i in driver.find_elements_by_xpath('//div[@class="_5pcr userContentWrapper"]//div[@data-testid="UFI2CommentsList/root_depth_0"]//a[@role="button"]'): 
            # 反覆偵測是否有「看更多留言」、「看更多回覆」與「看完整貼文內容」等按鈕，若有擇點擊
            if bool(re.search('comment|More|Repl',i.text)) == True :
                driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
                time.sleep(2)
                try:
                    driver.find_element_by_xpath('//div[@style="display: block;"]//a[@id="expanding_cta_close_button"]').click()
                except:
                    print('No pupup!')
                try:
                    i.click()
                except:
                    print('Nothing')
                time.sleep(2)
                k += 1

# %%
# 文章內容與互動摘要
def PostContent(soup):
    # po文區塊
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # po文人資訊區塊
    PosterInfo = userContent.find('div', {'class':'l_c3pyo2v0u i_c3pynyi2f clearfix'})
    # 互動摘要區(讚、留言與分享)
    feedback = soup.find('form', {'class':'commentable_item collapsed_comments'})
    # 名稱
    Name = PosterInfo.find('img').attrs['aria-label']
    # ID
    ID = PosterInfo.find('a', {'class':'_5pb8 o_c3pynyi2g _8o _8s lfloat _ohe'}).attrs['href'].split('/?',2)[0].split('/',-1)[-1]
    # 網址
    Link = driver.current_url
    # 發文時間
    try:
        Time = PosterInfo.find('abbr').attrs['title']
    except:
        Time = PosterInfo.find('div', {'class':'_1atc fsm fwn fcg'}).text
    # 文章內容
    try:
        Content = userContent.find('div', {'class':'_5pbx userContent _3576'}).text
    except:
        Content = ""
    # Like
    try:
        Like = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_LIKE'}).find('a').attrs['aria-label']
    except:
        Like = '0' 
    # Angry
    try:
        ANGER = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_ANGER'}).find('a').attrs['aria-label']
    except:
        ANGER = '0'
    # HAHA
    try:
        HAHA = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_HAHA'}).find('a').attrs['aria-label']
    except:
        HAHA = '0'
    # 留言
    try:
        commentcount = feedback.find('a', {'data-testid':'UFI2CommentsCount/root'}).text
    except:
        commentcount = '0'
    # 分享
    try:
        share = feedback.find('span', {'class':'_355t _4vn2'}).text
    except:
        share = '0' 
    return pd.DataFrame(
        data = [{'Name':Name,
                 'ID':ID,
                 'Link':Link,
                 'Time':Time,
                 'Content':Content,
                 'Like':Like,
                 'ANGER':ANGER,
                 "HAHA":HAHA,
                 'commentcount':commentcount,
                 'share':share}],
        columns = ['Name', 'ID', 'Time', 'Content', 'Like', 'ANGER', 'HAHA', 'commentcount', 'share', 'Link'])

# %%
def CrawlComment(soup):
    Comments = pd.DataFrame()
    # po文區塊
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # 用戶留言區
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # 回應貼文的留言
    for i in userContent.findAll('div', {'data-testid':'UFI2Comment/root_depth_0'}):
        try:
            CommentContent = i.find('span', {'dir':'ltr'}).text
        except:
            CommentContent = 'Sticker'
        Comment = pd.DataFrame(data = [{'CommentID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                 'CommentName':i.find('img').attrs['alt'],
                                 'CommentTime':i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'],
                                 'CommentContent':CommentContent,
                                 'Link':driver.current_url}],
                        columns = ['CommentID', 'CommentName', 'CommentTime', 'CommentContent', 'Link'])
        Comments = pd.concat([Comments, Comment], ignore_index=True)
    
    # 回應留言的留言
    for i in userContent.findAll('div', {'data-testid':'UFI2Comment/root_depth_1'}):
        try:
            CommentContent = i.find('span', {'dir':'ltr'}).text
        except:
            CommentContent = 'Sticker'
        Comment = pd.DataFrame(data = [{'CommentID':i.find('a', {'class':' _3mf5 _3mg1'}).attrs['data-hovercard'].split('id=',2)[1],
                                 'CommentName':i.find('img').attrs['alt'],
                                 'CommentTime':i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'],
                                 'CommentContent':CommentContent,
                                 'Link':driver.current_url}],
                        columns = ['CommentID', 'CommentName', 'CommentTime', 'CommentContent', 'Link'])
        Comments = pd.concat([Comments, Comment], ignore_index=True)        
    return Comments

# %%
# 直接執行 driver = webdriver.Chrome會報錯，()內要加上路徑

driver = webdriver.Chrome(executable_path=r'C:\Users\user\AppData\Local\Programs\Python\Python37-32\chromedriver.exe')
Links = FindLinks(url = 'https://www.facebook.com/vlsports/',
                  n = 10)
Links
# Out:
# ['https://www.facebook.com/vlsports/videos/2505639526367273/',
#  'https://www.facebook.com/vlsports/photos/a.155847187804450/2757487694307040/',
#  'https://www.facebook.com/vlsports/posts/2761764073879402',
#  'https://www.facebook.com/vlsports/posts/2761654090557067',
#  'https://www.facebook.com/vlsports/posts/2761396907249452',
#  'https://www.facebook.com/vlsports/photos/a.155847187804450/2757526767636466/',
#  'https://www.facebook.com/vlsports/videos/537724790266408/',
#  'https://www.facebook.com/vlsports/videos/155296132493990/',
#  'https://www.facebook.com/vlsports/videos/3672846519424082/',
#  'https://www.facebook.com/vlsports/posts/2754862584569551',
#  'https://www.facebook.com/vlsports/videos/226761495347197/',
#  'https://www.facebook.com/vlsports/videos/217046766174745/',
#  'https://www.facebook.com/vlsports/videos/1120694254946987/',
#  'https://www.facebook.com/vlsports/videos/1393835027489946/',
#  'https://www.facebook.com/vlsports/videos/1535287493319517/',
#  'https://www.facebook.com/vlsports/videos/209842153641626/',
#  'https://www.facebook.com/vlsports/videos/219505075823132/',
#  'https://www.facebook.com/vlsports/photos/a.457520470970452/2748875331834943/',
#  'https://www.facebook.com/vlsports/videos/2560348957626049/',
#  'https://www.facebook.com/vlsports/videos/2586031714984991/',
#  'https://www.facebook.com/vlsports/videos/641480523352661/',
#  'https://www.facebook.com/vlsports/photos/a.155847187804450/2726684610720682/',
#  'https://www.facebook.com/vlsports/videos/263805541317889/',
#  'https://www.facebook.com/vlsports/photos/a.155847187804450/2724774627578347/',
#  'https://www.facebook.com/vlsports/videos/2661163857439763/',
#  'https://www.facebook.com/vlsports/videos/635224427314436/',
#  'https://www.facebook.com/vlsports/videos/246687996723144/',
#  'https://www.facebook.com/vlsports/photos/a.155847187804450/2720356141353529/',
#  'https://www.facebook.com/vlsports/videos/1521664831323285/',
#  'https://www.facebook.com/vlsports/videos/158024212036161/',
#  'https://www.facebook.com/vlsports/videos/698840607521694/',
#  'https://www.facebook.com/vlsports/videos/137825447658771/',
#  'https://www.facebook.com/vlsports/videos/827942177724767/',
#  'https://www.facebook.com/vlsports/videos/231259601258531/',
#  'https://www.facebook.com/vlsports/photos/a.155847187804450/2709301259125684/',
#  'https://www.facebook.com/vlsports/photos/a.155847187804450/2709190975803379/',
#  'https://www.facebook.com/vlsports/videos/209073880344767/',
#  'https://www.facebook.com/vlsports/photos/a.155847187804450/2706824076040069/',
#  'https://www.facebook.com/vlsports/posts/2706391706083306']

# %%
driver.find_element_by_id("email").send_keys('e7569876@yahoo.com.tw') # 將 USERNAME改為你的臉書帳號
driver.find_element_by_id("pass").send_keys('e75983461') # 將 PASSWORD改為你的臉書密碼
driver.find_element_by_id("loginbutton").click()
time.sleep(3)

# %%
# 抓下來所有留言
PostsInformation = pd.DataFrame()
PostsComments = pd.DataFrame()
for i in Links:
    print('Dealing with: ' + i)
    try:
        expand(i)
        soup = BeautifulSoup(driver.page_source)
        PostsInformation = pd.concat([PostsInformation, PostContent(soup)],ignore_index=True)
        PostsComments = pd.concat([PostsComments, CrawlComment(soup)],ignore_index=True)
    except:
        print('Load Failed: ' + i)
# Out:
# Dealing with: https://www.facebook.com/vlsports/videos/2505639526367273/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/2505639526367273/
# Dealing with: https://www.facebook.com/vlsports/photos/a.155847187804450/2757487694307040/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.155847187804450/2757487694307040/
# Dealing with: https://www.facebook.com/vlsports/posts/2761764073879402
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/posts/2761764073879402
# Dealing with: https://www.facebook.com/vlsports/posts/2761654090557067
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/posts/2761654090557067
# Dealing with: https://www.facebook.com/vlsports/posts/2761396907249452
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/posts/2761396907249452
# Dealing with: https://www.facebook.com/vlsports/photos/a.155847187804450/2757526767636466/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.155847187804450/2757526767636466/
# Dealing with: https://www.facebook.com/vlsports/videos/537724790266408/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/537724790266408/
# Dealing with: https://www.facebook.com/vlsports/videos/155296132493990/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/155296132493990/
# Dealing with: https://www.facebook.com/vlsports/videos/3672846519424082/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/3672846519424082/
# Dealing with: https://www.facebook.com/vlsports/posts/2754862584569551
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/posts/2754862584569551
# Dealing with: https://www.facebook.com/vlsports/videos/226761495347197/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/226761495347197/
# Dealing with: https://www.facebook.com/vlsports/videos/217046766174745/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/217046766174745/
# Dealing with: https://www.facebook.com/vlsports/videos/1120694254946987/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/1120694254946987/
# Dealing with: https://www.facebook.com/vlsports/videos/1393835027489946/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/1393835027489946/
# Dealing with: https://www.facebook.com/vlsports/videos/1535287493319517/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/1535287493319517/
# Dealing with: https://www.facebook.com/vlsports/videos/209842153641626/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/209842153641626/
# Dealing with: https://www.facebook.com/vlsports/videos/219505075823132/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/219505075823132/
# Dealing with: https://www.facebook.com/vlsports/photos/a.457520470970452/2748875331834943/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.457520470970452/2748875331834943/
# Dealing with: https://www.facebook.com/vlsports/videos/2560348957626049/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/2560348957626049/
# Dealing with: https://www.facebook.com/vlsports/videos/2586031714984991/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/2586031714984991/
# Dealing with: https://www.facebook.com/vlsports/videos/641480523352661/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/641480523352661/
# Dealing with: https://www.facebook.com/vlsports/photos/a.155847187804450/2726684610720682/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.155847187804450/2726684610720682/
# Dealing with: https://www.facebook.com/vlsports/videos/263805541317889/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/263805541317889/
# Dealing with: https://www.facebook.com/vlsports/photos/a.155847187804450/2724774627578347/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.155847187804450/2724774627578347/
# Dealing with: https://www.facebook.com/vlsports/videos/2661163857439763/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/2661163857439763/
# Dealing with: https://www.facebook.com/vlsports/videos/635224427314436/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/635224427314436/
# Dealing with: https://www.facebook.com/vlsports/videos/246687996723144/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/246687996723144/
# Dealing with: https://www.facebook.com/vlsports/photos/a.155847187804450/2720356141353529/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.155847187804450/2720356141353529/
# Dealing with: https://www.facebook.com/vlsports/videos/1521664831323285/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/1521664831323285/
# Dealing with: https://www.facebook.com/vlsports/videos/158024212036161/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/158024212036161/
# Dealing with: https://www.facebook.com/vlsports/videos/698840607521694/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/698840607521694/
# Dealing with: https://www.facebook.com/vlsports/videos/137825447658771/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/137825447658771/
# Dealing with: https://www.facebook.com/vlsports/videos/827942177724767/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/827942177724767/
# Dealing with: https://www.facebook.com/vlsports/videos/231259601258531/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/231259601258531/
# Dealing with: https://www.facebook.com/vlsports/photos/a.155847187804450/2709301259125684/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.155847187804450/2709301259125684/
# Dealing with: https://www.facebook.com/vlsports/photos/a.155847187804450/2709190975803379/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.155847187804450/2709190975803379/
# Dealing with: https://www.facebook.com/vlsports/videos/209073880344767/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/videos/209073880344767/
# Dealing with: https://www.facebook.com/vlsports/photos/a.155847187804450/2706824076040069/
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/photos/a.155847187804450/2706824076040069/
# Dealing with: https://www.facebook.com/vlsports/posts/2706391706083306
# Now is in EN_US
# There is no comment!
# Load Failed: https://www.facebook.com/vlsports/posts/2706391706083306

# %%
PostsInformation
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
PostsComments
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
PostsInformation.to_excel('C:/Users/user/Desktop/建模Test/論文爬蟲/PostsInformation.xlsx')
PostsComments.to_excel('C:/Users/user/Desktop/建模Test/論文爬蟲/PostsComments.xlsx')
